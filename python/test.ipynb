# %%
print()
str
True
False
list
dict
tuple
var1 = 'tausif'
var2 = 2
var3 = [1,2,3]
var4= {'k1':1,'k2':2}
var5 = (1,2,3)
list1=list()
tuple1 = tuple()
dict1 = dict()
list2 = []
dict2 = {}
range()
enumerate()
for
if
elif
else
while
yeild

# %%
yield

# %%
var1 = 'tausif'

# %%
var1[::-1]
# Out:
# 'fisuat'

# %%
# str1= ""
# for i in range(len(var1),-1,1):
#     print(var1[i])
#     str1 +=var1[i]

# %%
str1
# Out:
# ''

# %%
range()
